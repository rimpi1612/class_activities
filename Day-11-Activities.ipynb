# %%
#1
import csv
import pandas as pd
from pathlib import Path
csvpath = Path('people.csv')
people_df = pd.read_csv(csvpath)
people_df.head()
# Out:
#     id first_name    last_name                            email  gender  \
# 0  1.0    Keriann    Lenormand  klenormand0@businessinsider.com  Female
# 1  2.0    Huntley        Rupke              hrupke1@reuters.com    Male
# 2  3.0     Gorden  Dalgarnowch      gdalgarnowch2@microsoft.com    Male
# 3  4.0     Cullie          NaN               cputten3@nymag.com    Male
# 4  5.0      Ariel    Strangman       astrangman4@bravesites.com  Female
#
#                                             uni_grad           job_title  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Income
# 0  58135.0
# 1  96053.0
# 2  59196.0
# 3  88493.0
# 4  89073.0

# %%
people_df.describe(include = "all")
# Out:
#           Person_ID   Last_Name First_Name Gender              University  \
# count    996.000000         990        993    998                     991
# unique          NaN         974        914      2                     939
# top             NaN  Ditchfield    Ailbert   Male  University of Portland
# freq            NaN           2          3    508                       3
# mean     500.213855         NaN        NaN    NaN                     NaN
# std      289.172174         NaN        NaN    NaN                     NaN
# min        1.000000         NaN        NaN    NaN                     NaN
# 25%      249.750000         NaN        NaN    NaN                     NaN
# 50%      500.000000         NaN        NaN    NaN                     NaN
# 75%      750.250000         NaN        NaN    NaN                     NaN
# max     1000.000000         NaN        NaN    NaN                     NaN
#
#                    Occupation         Salary                 Email
# ...

# %%
people_df["Income"].mean()
# Out:
# 84691.69338677355

# %%
people_df["Income"].median()
# Out:
# 84296.0

# %%
#2
people_df.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'gender', 'uni_grad',
#        'job_title', 'Income'],
#       dtype='object')

# %%
people_df.columns = ["Person_ID", "First_Name", "Last_Name", "Email", "Gender", "University", "Occupation", "Salary"]

# %%
people_df
# Out:
#      Person_ID First_Name    Last_Name                            Email  \
# 0          1.0    Keriann    Lenormand  klenormand0@businessinsider.com
# 1          2.0    Huntley        Rupke              hrupke1@reuters.com
# 2          3.0     Gorden  Dalgarnowch      gdalgarnowch2@microsoft.com
# 3          4.0     Cullie          NaN               cputten3@nymag.com
# 4          5.0      Ariel    Strangman       astrangman4@bravesites.com
# ..         ...        ...          ...                              ...
# 995      996.0       Meta     Crumpton               mcrumptonrn@qq.com
# 996      997.0      Gunar      Gilford             ggilfordro@yandex.ru
# 997      998.0   Lucretia      Gurling                 lgurlingrp@de.vu
# 998      999.0     Andrew         Yang             ayang@codedrills.com
# 999     1000.0     Andrew         Yang             ayang@codedrills.com
#
#      Gender                                         University  \
# ...

# %%
people_df = people_df[["Person_ID", "Last_Name", "First_Name", "Gender", "University", "Occupation", "Salary", "Email"]]
people_df.head()
# Out:
#    Person_ID    Last_Name First_Name  Gender  \
# 0        1.0    Lenormand    Keriann  Female
# 1        2.0        Rupke    Huntley    Male
# 2        3.0  Dalgarnowch     Gorden    Male
# 3        4.0          NaN     Cullie    Male
# 4        5.0    Strangman      Ariel  Female
#
#                                           University          Occupation  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Salary                            Email
# 0  58135.0  klenormand0@businessinsider.com
# 1  96053.0              hrupke1@reuters.com
# 2  59196.0      gdalgarnowch2@microsoft.com
# 3  88493.0               cputten3@nymag.com
# ...

# %%
people_df.columns
# Out:
# Index(['Person_ID', 'Last_Name', 'First_Name', 'Gender', 'University',
#        'Occupation', 'Salary', 'Email', 'Age'],
#       dtype='object')

# %%
people_df.shape
# Out:
# (1000, 9)

# %%
people_df.dtypes
# Out:
# Person_ID     float64
# Last_Name      object
# First_Name     object
# Gender         object
# University     object
# Occupation     object
# Salary        float64
# Email          object
# Age             int64
# Age Copy        int64
# dtype: object

# %%
import numpy as np
age = np.random.randint(22, 65, size=1000)

# %%
people_df['Age'] = age
people_df['Age Copy'] = age
# Out:
# <ipython-input-19-7594f1a90ed3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   people_df['Age'] = age
# <ipython-input-19-7594f1a90ed3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   people_df['Age Copy'] = age

# %%
people_df.shape
# Out:
# (1000, 10)

# %%
people_df.columns
# Out:
# Index(['Person_ID', 'Last_Name', 'First_Name', 'Gender', 'University',
#        'Occupation', 'Salary', 'Email', 'Age', 'Age Copy'],
#       dtype='object')

# %%
people_df.drop(columns="Age Copy")
# Out:
#      Person_ID    Last_Name First_Name  Gender  \
# 0          1.0    Lenormand    Keriann  Female
# 1          2.0        Rupke    Huntley    Male
# 2          3.0  Dalgarnowch     Gorden    Male
# 3          4.0          NaN     Cullie    Male
# 4          5.0    Strangman      Ariel  Female
# ..         ...          ...        ...     ...
# 995      996.0     Crumpton       Meta  Female
# 996      997.0      Gilford      Gunar    Male
# 997      998.0      Gurling   Lucretia  Female
# 998      999.0         Yang     Andrew    Male
# 999     1000.0         Yang     Andrew    Male
#
#                                             University             Occupation  \
# 0                                    Aurora University     Nurse Practicioner
# 1                        Osaka University of Economics        Project Manager
# 2                                    Ludong University     Environmental Tech
# 3    Université des Sciences et de la Technologie d...        Legal Assistant
# ...

# %%
people_df.to_csv("people_changed.csv")

# %%
#3
people_reorder_df = pd.read_csv("people_reordered.csv")
people_reorder_df.head()
# Out:
#    Unnamed: 0  Person_ID    Last_Name First_Name  Gender  \
# 0           0        1.0    Lenormand    Keriann  Female
# 1           1        2.0        Rupke    Huntley    Male
# 2           2        3.0  Dalgarnowch     Gorden    Male
# 3           3        4.0          NaN     Cullie    Male
# 4           4        5.0    Strangman      Ariel  Female
#
#                                           University          Occupation  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Salary                            Email  Age
# 0  58135.0  klenormand0@businessinsider.com   27
# 1  96053.0              hrupke1@reuters.com   22
# ...

# %%
people_reorder_df.dtypes
# Out:
# Unnamed: 0      int64
# Person_ID     float64
# Last_Name      object
# First_Name     object
# Gender         object
# University     object
# Occupation     object
# Salary        float64
# Email          object
# Age             int64
# dtype: object

# %%
people_reorder_df =people_reorder_df.drop(columns="Unnamed: 0")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-c1dd987e4e30> in <module>
# ----> 1 people_reorder_df =people_reorder_df.drop(columns="Unnamed: 0")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
people_reorder_df.shape
# Out:
# (1000, 9)

# %%
people_reorder_df.count()
# Out:
# Person_ID      996
# Last_Name      990
# First_Name     993
# Gender         998
# University     991
# Occupation     998
# Salary         998
# Email          992
# Age           1000
# dtype: int64

# %%
people_reorder_df["First_Name"].value_counts()
# Out:
# Unnamed     6
# Ailbert     3
# Israel      3
# Rachel      2
# Gilles      2
#            ..
# Bobbette    1
# Bell        1
# Agnesse     1
# Gage        1
# Korey       1
# Name: First_Name, Length: 895, dtype: int64

# %%
people_reorder_df.isnull().any()
# Out:
# Person_ID      True
# Last_Name      True
# First_Name     True
# Gender         True
# University     True
# Occupation     True
# Salary         True
# Email          True
# Age           False
# dtype: bool

# %%
people_reorder_df.isnull().sum()
# Out:
# Person_ID      4
# Last_Name     10
# First_Name     7
# Gender         2
# University     9
# Occupation     2
# Salary         2
# Email          8
# Age            0
# dtype: int64

# %%
len(people_reorder_df.index)
# Out:
# 1000

# %%
people_reorder_df.isnull().sum()/len(people_reorder_df.index)*100
# Out:
# Person_ID     0.4
# Last_Name     1.0
# First_Name    0.7
# Gender        0.2
# University    0.9
# Occupation    0.2
# Salary        0.2
# Email         0.8
# Age           0.0
# dtype: float64

# %%
people_reorder_df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999     True
# Length: 1000, dtype: bool

# %%
people_reorder_df.duplicated(["First_Name"],keep=False)
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998     True
# 999     True
# Length: 1000, dtype: bool

# %%
people_reorder_df.duplicated(["Last_Name"],keep=False)
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998     True
# 999     True
# Length: 1000, dtype: bool

# %%
people_reorder_df["First_Name"]=people_reorder_df["First_Name"].fillna("Unnamed")

# %%
people_reorder_df["Last_Name"]=people_reorder_df["Last_Name"].fillna("Unnamed")

# %%
people_reorder_df.dropna(inplace = True)

# %%
people_reorder_df.isnull().sum()
# Out:
# Person_ID     0
# Last_Name     0
# First_Name    0
# Gender        0
# University    0
# Occupation    0
# Salary        0
# Email         0
# Age           0
# dtype: int64

# %%
people_reorder_df.drop_duplicates(subset=["First_Name","Last_Name"],keep=False)
# Out:
#      Person_ID    Last_Name First_Name  Gender  \
# 0          1.0    Lenormand    Keriann  Female
# 1          2.0        Rupke    Huntley    Male
# 2          3.0  Dalgarnowch     Gorden    Male
# 3          4.0      Unnamed     Cullie    Male
# 4          5.0    Strangman      Ariel  Female
# ..         ...          ...        ...     ...
# 993      994.0    Griffitts    Damaris  Female
# 994      995.0       Jeacop       Iggy    Male
# 995      996.0     Crumpton       Meta  Female
# 996      997.0      Gilford      Gunar    Male
# 997      998.0      Gurling   Lucretia  Female
#
#                                             University             Occupation  \
# 0                                    Aurora University     Nurse Practicioner
# 1                        Osaka University of Economics        Project Manager
# 2                                    Ludong University     Environmental Tech
# 3    Université des Sciences et de la Technologie d...        Legal Assistant
# ...

# %%
people_reorder_df["Person_ID"] = people_reorder_df["Person_ID"].astype("int")

# %%
people_reorder_df.dtypes
# Out:
# Person_ID       int64
# Last_Name      object
# First_Name     object
# Gender         object
# University     object
# Occupation     object
# Salary        float64
# Email          object
# Age             int64
# dtype: object

# %%
people_reorder_df.to_csv("people_re_changed.csv")

# %%
#4
people_cleansed_df = pd.read_csv("people_cleansed.csv")
people_cleansed_df.head()
# Out:
#    Person_ID    Last_Name First_Name  Gender  \
# 0          1    Lenormand    Keriann  Female
# 1          2        Rupke    Huntley    Male
# 2          3  Dalgarnowch     Gorden    Male
# 3          4      Unnamed     Cullie    Male
# 4          5    Strangman      Ariel  Female
#
#                                           University          Occupation  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Salary                            Email  Age
# 0  58135.0  klenormand0@businessinsider.com   27
# 1  96053.0              hrupke1@reuters.com   22
# 2  59196.0      gdalgarnowch2@microsoft.com   40
# 3  88493.0               cputten3@nymag.com   62
# ...

# %%
people_cleansed_df.iloc[:]
# Out:
#      Person_ID    Last_Name First_Name  Gender  \
# 0            1    Lenormand    Keriann  Female
# 1            2        Rupke    Huntley    Male
# 2            3  Dalgarnowch     Gorden    Male
# 3            4      Unnamed     Cullie    Male
# 4            5    Strangman      Ariel  Female
# ..         ...          ...        ...     ...
# 968        996     Crumpton       Meta  Female
# 969        997      Gilford      Gunar    Male
# 970        998      Gurling   Lucretia  Female
# 971        999         Yang     Andrew    Male
# 972        999         Yang     Andrew    Male
#
#                                             University             Occupation  \
# 0                                    Aurora University     Nurse Practicioner
# 1                        Osaka University of Economics        Project Manager
# 2                                    Ludong University     Environmental Tech
# 3    Université des Sciences et de la Technologie d...        Legal Assistant
# ...

# %%
people_cleansed_df.iloc[0]
# Out:
# Person_ID                                   1
# Last_Name                           Lenormand
# First_Name                            Keriann
# Gender                                 Female
# University                  Aurora University
# Occupation                 Nurse Practicioner
# Salary                                58135.0
# Email         klenormand0@businessinsider.com
# Age                                        27
# Name: 0, dtype: object

# %%
people_cleansed_df.iloc[0:10]
# Out:
#    Person_ID    Last_Name  First_Name  Gender  \
# 0          1    Lenormand     Keriann  Female
# 1          2        Rupke     Huntley    Male
# 2          3  Dalgarnowch      Gorden    Male
# 3          4      Unnamed      Cullie    Male
# 4          5    Strangman       Ariel  Female
# 5          6    Snozzwell     Antonio    Male
# 6          7     Neathway       Darya  Female
# 7          8       Duding     Helaina  Female
# 8          9   Franzolini  Gerhardine  Female
# 9         10        Traut       Charo  Female
#
#                                           University  \
# 0                                  Aurora University
# 1                      Osaka University of Economics
# 2                                  Ludong University
# 3  Université des Sciences et de la Technologie d...
# 4                             Boise State University
# 5                                 Babcock University
# 6                                     Molloy College
# ...

# %%
people_cleansed_df.iloc[:]
# Out:
#      Person_ID    Last_Name First_Name  Gender  \
# 0            1    Lenormand    Keriann  Female
# 1            2        Rupke    Huntley    Male
# 2            3  Dalgarnowch     Gorden    Male
# 3            4      Unnamed     Cullie    Male
# 4            5    Strangman      Ariel  Female
# ..         ...          ...        ...     ...
# 968        996     Crumpton       Meta  Female
# 969        997      Gilford      Gunar    Male
# 970        998      Gurling   Lucretia  Female
# 971        999         Yang     Andrew    Male
# 972        999         Yang     Andrew    Male
#
#                                             University             Occupation  \
# 0                                    Aurora University     Nurse Practicioner
# 1                        Osaka University of Economics        Project Manager
# 2                                    Ludong University     Environmental Tech
# 3    Université des Sciences et de la Technologie d...        Legal Assistant
# ...

# %%
people_cleansed_df.iloc[-1]
# Out:
# Person_ID                                       999
# Last_Name                                      Yang
# First_Name                                   Andrew
# Gender                                         Male
# University    Rutgers University School of Business
# Occupation                      Curriculum Engineer
# Salary                                      60000.0
# Email                          ayang@codedrills.com
# Age                                              53
# Name: 972, dtype: object

# %%
people_cleansed_df.iloc[:,1]
# Out:
# 0        Lenormand
# 1            Rupke
# 2      Dalgarnowch
# 3          Unnamed
# 4        Strangman
#           ...
# 968       Crumpton
# 969        Gilford
# 970        Gurling
# 971           Yang
# 972           Yang
# Name: Last_Name, Length: 973, dtype: object

# %%
people_cleansed_df.iloc[:,-1]
# Out:
# 0      27
# 1      22
# 2      40
# 3      62
# 4      47
#        ..
# 968    52
# 969    32
# 970    48
# 971    53
# 972    53
# Name: Age, Length: 973, dtype: int64

# %%
people_cleansed_df.iloc[:,[0,1,3]]
# Out:
#      Person_ID    Last_Name  Gender
# 0            1    Lenormand  Female
# 1            2        Rupke    Male
# 2            3  Dalgarnowch    Male
# 3            4      Unnamed    Male
# 4            5    Strangman  Female
# ..         ...          ...     ...
# 968        996     Crumpton  Female
# 969        997      Gilford    Male
# 970        998      Gurling  Female
# 971        999         Yang    Male
# 972        999         Yang    Male
#
# [973 rows x 3 columns]

# %%
people_cleansed_df.iloc[[0,2,4],[1,3,5]]
# Out:
#      Last_Name  Gender          Occupation
# 0    Lenormand  Female  Nurse Practicioner
# 2  Dalgarnowch    Male  Environmental Tech
# 4    Strangman  Female     Project Manager

# %%
people_cleansed_df.iloc[0:5,[2,3,4]]
# Out:
#   First_Name  Gender                                         University
# 0    Keriann  Female                                  Aurora University
# 1    Huntley    Male                      Osaka University of Economics
# 2     Gorden    Male                                  Ludong University
# 3     Cullie    Male  Université des Sciences et de la Technologie d...
# 4      Ariel  Female                             Boise State University

# %%
people_cleansed_df.iloc[0,people_cleansed_df.columns.get_loc("First_Name")] = "SYEDA HASAN"
people_cleansed_df.head()
# Out:
#    Person_ID    Last_Name   First_Name  Gender  \
# 0          1    Lenormand  SYEDA HASAN  Female
# 1          2        Rupke      Huntley    Male
# 2          3  Dalgarnowch       Gorden    Male
# 3          4      Unnamed       Cullie    Male
# 4          5    Strangman        Ariel  Female
#
#                                           University          Occupation  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Salary                            Email  Age
# 0  58135.0  klenormand0@businessinsider.com   27
# 1  96053.0              hrupke1@reuters.com   22
# 2  59196.0      gdalgarnowch2@microsoft.com   40
# ...

# %%
people_cleansed_df.set_index(people_cleansed_df["First_Name"], inplace=True)
people_cleansed_df.sample(5)
# Out:
#             Person_ID Last_Name First_Name  Gender  \
# First_Name
# Bary              731      Gohn       Bary    Male
# Wally             136   Barrell      Wally  Female
# Giana             721    Kindon      Giana  Female
# Israel            768   Butters     Israel    Male
# Merle             728    Bolton      Merle    Male
#
#                                              University  \
# First_Name
# Bary        University of North Carolina at Chapel Hill
# Wally                              Merlimau Polytechnic
# Giana                          Dammam Community College
# Israel                     Nara University of Education
# Merle           National University of Modern Languages
#
#                            Occupation    Salary  \
# First_Name
# Bary         Environmental Specialist  107950.0
# Wally                Product Engineer   53077.0
# Giana               Director of Sales   65746.0
# Israel      Account Representative II   54117.0
# ...

# %%
people_cleansed_df.sort_index()
# Out:
#             Person_ID      Last_Name First_Name  Gender  \
# First_Name
# Aaron             461       De Brett      Aaron    Male
# Abbot             459      McGaughey      Abbot    Male
# Abbye             125      MacKnight      Abbye  Female
# Abner             158  Christauffour      Abner    Male
# Abra              177         Vawton       Abra  Female
# ...               ...            ...        ...     ...
# Zachariah         825           Akid  Zachariah    Male
# Zandra            816     Kollaschek     Zandra  Female
# Zebulon            58      Josefovic    Zebulon    Male
# Zerk               59       Goulston       Zerk    Male
# Zsazsa             81        Cutajar     Zsazsa  Female
#
#                                                    University  \
# First_Name
# Aaron                                      Tsurumi University
# Abbot                                 University of Mauritius
# Abbye                               Savannah State University
# ...

# %%
people_cleansed_df.loc[people_cleansed_df["First_Name"] == "Andrew"]
# Out:
#             Person_ID Last_Name First_Name Gender  \
# First_Name
# Andrew            999      Yang     Andrew   Male
# Andrew            999      Yang     Andrew   Male
#
#                                        University           Occupation  \
# First_Name
# Andrew      Rutgers University School of Business  Curriculum Engineer
# Andrew      Rutgers University School of Business  Curriculum Engineer
#
#              Salary                 Email  Age
# First_Name
# Andrew      60000.0  ayang@codedrills.com   53
# Andrew      60000.0  ayang@codedrills.com   53

# %%
people_cleansed_df.loc['Andrew':'Vonnie']
# Out:
# Empty DataFrame
# Columns: [Person_ID, Last_Name, First_Name, Gender, University, Occupation, Salary, Email, Age]
# Index: []

# %%
people_cleansed_df.loc[people_cleansed_df["Gender"] == "Male"]
# Out:
#             Person_ID    Last_Name First_Name Gender  \
# First_Name
# Huntley             2        Rupke    Huntley   Male
# Gorden              3  Dalgarnowch     Gorden   Male
# Cullie              4      Unnamed     Cullie   Male
# Antonio             6    Snozzwell    Antonio   Male
# Horst              11       Crepin      Horst   Male
# ...               ...          ...        ...    ...
# Julian            991    Hampshire     Julian   Male
# Iggy              995       Jeacop       Iggy   Male
# Gunar             997      Gilford      Gunar   Male
# Andrew            999         Yang     Andrew   Male
# Andrew            999         Yang     Andrew   Male
#
#                                                    University  \
# First_Name
# Huntley                         Osaka University of Economics
# Gorden                                      Ludong University
# Cullie      Université des Sciences et de la Technologie d...
# ...

# %%
people_cleansed_df.loc[people_cleansed_df["First_Name"] == "Aron"]["First_Name"] = "Arod"
# Out:
# <ipython-input-157-71646503876f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   people_cleansed_df.loc[people_cleansed_df["First_Name"] == "Aron"]["First_Name"] = "Arod"

# %%
people_cleansed_df.loc[people_cleansed_df["First_Name"] == "Aron"]
# Out:
#             Person_ID Last_Name First_Name Gender            University  \
# First_Name
# Aron              581    Collie       Aron   Male  Roosevelt University
#
#                  Occupation    Salary                Email  Age
# First_Name
# Aron        General Manager  107433.0  acollieg4@desdev.cn   50

# %%
#5
people_cleansed_df.sort_index()
# Out:
#             Person_ID      Last_Name First_Name  Gender  \
# First_Name
# Aaron             461       De Brett      Aaron    Male
# Abbot             459      McGaughey      Abbot    Male
# Abbye             125      MacKnight      Abbye  Female
# Abner             158  Christauffour      Abner    Male
# Abra              177         Vawton       Abra  Female
# ...               ...            ...        ...     ...
# Zachariah         825           Akid  Zachariah    Male
# Zandra            816     Kollaschek     Zandra  Female
# Zebulon            58      Josefovic    Zebulon    Male
# Zerk               59       Goulston       Zerk    Male
# Zsazsa             81        Cutajar     Zsazsa  Female
#
#                                                    University  \
# First_Name
# Aaron                                      Tsurumi University
# Abbot                                 University of Mauritius
# Abbye                               Savannah State University
# ...

# %%
people_cleansed_df.sort_index(ascending=False)
# Out:
#             Person_ID      Last_Name First_Name  Gender  \
# First_Name
# Zsazsa             81        Cutajar     Zsazsa  Female
# Zerk               59       Goulston       Zerk    Male
# Zebulon            58      Josefovic    Zebulon    Male
# Zandra            816     Kollaschek     Zandra  Female
# Zachariah         825           Akid  Zachariah    Male
# ...               ...            ...        ...     ...
# Abra              177         Vawton       Abra  Female
# Abner             158  Christauffour      Abner    Male
# Abbye             125      MacKnight      Abbye  Female
# Abbot             459      McGaughey      Abbot    Male
# Aaron             461       De Brett      Aaron    Male
#
#                                                    University  \
# First_Name
# Zsazsa      Asia Pacific Institute of Information Technolo...
# Zerk                    Universidad Tecnologica de la Mixteca
# Zebulon                               Rajiv Gandhi University
# ...

# %%
#6
people_cleansed_df.groupby("Occupation").head(10)
# Out:
#              Person_ID    Last_Name   First_Name  Gender  \
# First_Name
# SYEDA HASAN          1    Lenormand  SYEDA HASAN  Female
# Huntley              2        Rupke      Huntley    Male
# Gorden               3  Dalgarnowch       Gorden    Male
# Cullie               4      Unnamed       Cullie    Male
# Ariel                5    Strangman        Ariel  Female
# ...                ...          ...          ...     ...
# Iggy               995       Jeacop         Iggy    Male
# Meta               996     Crumpton         Meta  Female
# Lucretia           998      Gurling     Lucretia  Female
# Andrew             999         Yang       Andrew    Male
# Andrew             999         Yang       Andrew    Male
#
#                                                     University  \
# First_Name
# SYEDA HASAN                                  Aurora University
# Huntley                          Osaka University of Economics
# ...

# %%
people_cleansed_df.groupby("Salary").mean()
# Out:
#           Person_ID   Age
# Salary
# 50013.0        41.0  58.0
# 50138.0       448.0  53.0
# 50176.0       340.0  60.0
# 50184.0       497.0  50.0
# 50304.0       911.0  28.0
# ...             ...   ...
# 119916.0        6.0  49.0
# 119918.0       36.0  55.0
# 119942.0      570.0  50.0
# 119962.0      605.0  40.0
# 119987.0       32.0  45.0
#
# [968 rows x 2 columns]

# %%
bins = [ 0, 30000, 70000, 100000,200000]
labels = ['Low', 'Moderate', 'Above Average','High']

# %%
bins
labels
# Out:
# ['Low', 'Moderate', 'Above Average', 'High']

# %%
people_cleansed_df['Salary Level'] = pd.cut(people_cleansed_df['Salary'], bins=bins, labels=labels)
people_cleansed_df
# Out:
#              Person_ID    Last_Name   First_Name  Gender  \
# First_Name
# SYEDA HASAN          1    Lenormand  SYEDA HASAN  Female
# Huntley              2        Rupke      Huntley    Male
# Gorden               3  Dalgarnowch       Gorden    Male
# Cullie               4      Unnamed       Cullie    Male
# Ariel                5    Strangman        Ariel  Female
# ...                ...          ...          ...     ...
# Meta               996     Crumpton         Meta  Female
# Gunar              997      Gilford        Gunar    Male
# Lucretia           998      Gurling     Lucretia  Female
# Andrew             999         Yang       Andrew    Male
# Andrew             999         Yang       Andrew    Male
#
#                                                     University  \
# First_Name
# SYEDA HASAN                                  Aurora University
# Huntley                          Osaka University of Economics
# ...

# %%
#8
# %matplotlib inline

# %%
msft_df = pd.read_csv("MSFT.csv")
msft_df.head()
# Out:
#      date  close    volume   open   high    low
# 0  8/3/09  23.83  46843710  23.82  23.86  23.50
# 1  8/4/09  23.77  49116380  23.68  23.79  23.53
# 2  8/5/09  23.81  53263040  23.84  24.25  23.79
# 3  8/6/09  23.46  59655950  23.93  23.98  23.27
# 4  8/7/09  23.56  46165010  23.75  23.82  23.50

# %%
msft_df = msft_df.drop(columns=["volume","open","high","low"])

# %%
msft_df.head()
# Out:
#      date  close
# 0  8/3/09  23.83
# 1  8/4/09  23.77
# 2  8/5/09  23.81
# 3  8/6/09  23.46
# 4  8/7/09  23.56

# %%
msft_df["date"]=pd.to_datetime(msft_df["date"],infer_datetime_format=True)
msft_df.head()
# Out:
#         date  close
# 0 2009-08-03  23.83
# 1 2009-08-04  23.77
# 2 2009-08-05  23.81
# 3 2009-08-06  23.46
# 4 2009-08-07  23.56

# %%
msft_df.set_index("date")
# Out:
#              close
# date
# 2009-08-03   23.83
# 2009-08-04   23.77
# 2009-08-05   23.81
# 2009-08-06   23.46
# 2009-08-07   23.56
# ...            ...
# 2019-07-26  141.34
# 2019-07-29  141.03
# 2019-07-30  140.35
# 2019-07-31  136.27
# 2019-08-01  138.06
#
# [2517 rows x 1 columns]

# %%
msft_df.plot()
# Out:
# <AxesSubplot:>

# %%
daily_returns = msft_df["close"].pct_change(1)

# %%
daily_returns.plot()
# Out:
# <AxesSubplot:>

# %%
cumulative_returns = (1 + daily_returns).cumprod()
cumulative_returns.head()
# Out:
# 0         NaN
# 1    0.997482
# 2    0.999161
# 3    0.984473
# 4    0.988670
# Name: close, dtype: float64

# %%
cumulative_returns.plot()
# Out:
# <AxesSubplot:>

# %%
#9
roll_mean_7= msft_df.rolling(window=7).mean().plot()

# %%
roll_std_7= msft_df.rolling(window=7).std().plot()
